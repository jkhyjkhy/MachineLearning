# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split

(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28*28)
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
dense1 = keras.layers.Dense(100, activation='sigmoid', input_shape=(784,))

#출력층에서 10개의 클래스를 분류하므로 10개의 뉴런, 소프트맥스 활성화함수
dense2 = keras.layers.Dense(10, activation='softmax')

# %%
model = keras.Sequential([dense1, dense2])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = keras.Sequential([
                          keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name='hidden'),
                          keras.layers.Dense(10, activation='softmax', name="output")
], name='패션 MNIST모델')

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.5594 - accuracy: 0.8096
# Epoch 2/5
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4075 - accuracy: 0.8539
# Epoch 3/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3732 - accuracy: 0.8659
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3509 - accuracy: 0.8726
# Epoch 5/5
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3343 - accuracy: 0.8795

# %% [markdown]
# 렐루 함수

# %%
model.add(keras.layers.Flatten(input_shape=(28, 28)))

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_4 (Dense)             (None, 100)               78500
#
#  dense_5 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5489 - accuracy: 0.8075
# Epoch 2/5
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.4000 - accuracy: 0.8559
# Epoch 3/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3596 - accuracy: 0.8693
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3354 - accuracy: 0.8800
# Epoch 5/5
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3210 - accuracy: 0.8856

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8758
# [0.3586386442184448, 0.8758333325386047]

# %% [markdown]
# 확률적 경사 하강법

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics='accuracy')
sgd = keras.optimizers.SGD()
model.compile(optimizer=sgd, loss='sparse_categorical_crossentropy', metrics='accuracy')
sgd = keras.optimizers.SGD(learning_rate=0.1)
sgd = keras.optimizers.SGD(momentum=0.9, nesterov=True)
adagrad = keras.optimizers.Adagrad()
model.compile(optimizer=adagrad, loss='sparse_categorical_crossentropy', metrics='accuracy')
rmsprop = keras.optimizers.RMSprop()
model.compile(optimizer=rmsprop, loss='sparse_categorical_crossentropy', metrics='accuracy')
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5291 - accuracy: 0.8132
# Epoch 2/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3990 - accuracy: 0.8572
# Epoch 3/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3581 - accuracy: 0.8682
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3308 - accuracy: 0.8770
# Epoch 5/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3099 - accuracy: 0.8863

# %%
model.evaluate(val_scaled, val_target)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-beea57f23231> in <module>
# ----> 1 sgd = keras.optimizers(momontum=0.9, nesterov=True)
#
# TypeError: 'module' object is not callable
